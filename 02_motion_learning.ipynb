# %%
import os
dir=os.getcwd()
basename=os.path.basename(dir)
print(basename)

if basename != 'part_1':
    os.chdir("./part_1")

print(f"current working dir is: {os.getcwd()}")
# Out:
# part_1
# current working dir is: d:\BaiduSyncdisk\RC3\DXL_SKILL_MODULE\Robotic_Skill_Module_2023\part_1

# %%
# !python motionLearning.py --devicename COM3 --connected_motors 1 2 3 --moving_speed 150 --max_learning_steps 500
# Out:
# Succeeded to open the port
# Succeeded to change the baudrate
# ID:001  PresPos:356
# Moving speed of dxl ID: 1 set to 150
# ID:002  PresPos:397
# Moving speed of dxl ID: 2 set to 150
# [TxRxResult] There is no status packet!
# ID:003  PresPos:000
# [TxRxResult] There is no status packet!
# Moving speed of dxl ID: 3 set to 150
# 0
# 0
# [TxRxResult] There is no status packet!
# [TxRxResult] There is no status packet!
# 0
# ID:001  PresPos:356
# ID:002  PresPos:399
# [TxRxResult] There is no status packet!
# ID:003  PresPos:000
# ID:001  PresPos:356
# ID:002  PresPos:399
# [TxRxResult] There is no status packet!
# ID:003  PresPos:000
# ID:001  PresPos:356
# ID:002  PresPos:399
# [TxRxResult] There is no status packet!
# ID:003  PresPos:000
# ID:001  PresPos:356
# ID:002  PresPos:399
# [TxRxResult] There is no status packet!
# ID:003  PresPos:000
# ID:001  PresPos:356
# ID:002  PresPos:399
# [TxRxResult] There is no status packet!
# ID:003  PresPos:000
# ID:001  PresPos:356
# ...
