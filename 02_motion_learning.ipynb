# %%
import os
dir=os.getcwd()
basename=os.path.basename(dir)
print(basename)

if basename != 'part_1':
    os.chdir("./part_1")

print(f"current working dir is: {os.getcwd()}")
# Out:
# RC3-Mechatronics
# current working dir is: d:\BaiduSyncdisk\RC3\DXL_SKILL_MODULE\RC3-Mechatronics\part_1

# %%
# !python motionLearning.py --devicename COM3 --connected_motors 0 1 2 --moving_speed 150 --max_learning_steps 500
# Out:
# Succeeded to open the port
# Succeeded to change the baudrate
# ID:000  PresPos:511
# Moving speed of dxl ID: 0 set to 150
# ID:001  PresPos:517
# Moving speed of dxl ID: 1 set to 150
# ID:002  PresPos:830
# Moving speed of dxl ID: 2 set to 150
# 0
# 0
# 0
# ID:000  PresPos:511
# ID:001  PresPos:517
# ID:002  PresPos:831
# ID:000  PresPos:510
# ID:001  PresPos:517
# ID:002  PresPos:831
# ID:000  PresPos:511
# ID:001  PresPos:517
# ID:002  PresPos:831
# ID:000  PresPos:511
# ID:001  PresPos:517
# ID:002  PresPos:831
# ID:000  PresPos:511
# ID:001  PresPos:517
# ID:002  PresPos:831
# ID:000  PresPos:511
# ID:001  PresPos:517
# ID:002  PresPos:831
# ID:000  PresPos:511
# ID:001  PresPos:517
# ID:002  PresPos:831
# ID:000  PresPos:511
# ID:001  PresPos:517
# ID:002  PresPos:831
# ID:000  PresPos:511
# ID:001  PresPos:517
# ID:002  PresPos:831
# ID:000  PresPos:511
# ID:001  PresPos:517
# ID:002  PresPos:831
# ID:000  PresPos:511
# ID:001  PresPos:517
# ID:002  PresPos:831
# ...
