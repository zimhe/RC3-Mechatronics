# %%
import os
dir=os.getcwd()
basename=os.path.basename(dir)
print(basename)

if basename != 'part_2':
    os.chdir("./part_2")

print(f"current working dir is: {os.getcwd()}")

# %%
# !python dxl_osc_main.py
