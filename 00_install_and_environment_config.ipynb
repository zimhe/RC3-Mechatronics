# %% [markdown]
# **Create Virtual Environment**

# %%
import subprocess
import os

subprocess.run(["python", "-m", "venv", ".venv"])
# Out:
# CompletedProcess(args=['python', '-m', 'venv', '.venv'], returncode=0)

# %% [markdown]
# **Install Packages**

# %%
# install the requirements into the virtual envrionment：
venv_python = os.path.join(".venv", "Scripts", "python.exe")  # Windows
subprocess.run([venv_python, "-m", "pip", "install", "-r", "requirements.txt"])
# Out:
# CompletedProcess(args=['.venv\\Scripts\\python.exe', '-m', 'pip', 'install', '-r', 'requirements.txt'], returncode=0)

# %% [markdown]
# Might need re-open this project after installing
